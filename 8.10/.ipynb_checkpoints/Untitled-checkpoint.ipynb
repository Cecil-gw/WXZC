# %%
import sys
print(sys.executable)
# Out:
# D:\wx26.7.14\venv312\Scripts\python.exe

# %%
import torch

X = torch.tensor([1,2,3])
A = X.numpy()
B = torch.tensor(A)

print(type(A), type(B))
# Out:
# <class 'numpy.ndarray'> <class 'torch.Tensor'>
